# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Gupta Ji\\Downloads'

# %%
os.chdir("C:\\Users\\Gupta Ji\\Downloads")

# %%
df=pd.read_csv("Messages.csv")

# %%
df.head()
# Out:
#                                               1 desk
# 0         flat pack desk, cupboard, pedestal drawers
# 1                                 door step delivery
# 2                                       ground floor
# 3  No number i'm afraid - i can wait here on the web
# 4                                          1 day bed

# %%
#df=['basement','delivery','level']

# %%
#df.count("basement")

# %%
#import collections

# %%
#collections.Counter(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5878 entries, 0 to 5877
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1 desk  5878 non-null   object
# dtypes: object(1)
# memory usage: 46.0+ KB

# %%
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
nltk.download('punkt') 
from collections import Counter
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Gupta
# [nltk_data]     Ji\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#word_freq = FreqDist(word)

# %%
text="df"

# %%
words = text.split()

# %%
word_freq = Counter(words)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'white',stopwords = stopword).generate(str(df))

plt.rcParams['figure.figsize'] = (12,8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular word',fontsize = 30)
plt.axis('off')
plt.show()

# %%
print("Word frequencies:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word frequencies:
# df: 1

# %%
print("Word frequencies:")
for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# Word frequencies:
# df: 1
